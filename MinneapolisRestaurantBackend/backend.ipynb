# %%
# Import Dependencies

import requests
import json
import pandas as pd
import numpy as np
import datetime
from config import yelp_key
from config import google_key
from config import foursquare_id
from config import foursquare_secret
import time
import datetime
from difflib import SequenceMatcher

from config import password
from config import username
import psycopg2
import sqlalchemy
import urllib
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import PrimaryKeyConstraint
from sqlalchemy.orm import Session
from sqlalchemy.orm import sessionmaker
from sqlalchemy import Column, Integer, String, Float, DateTime
from sqlalchemy.schema import Sequence

print(f'Dependencies imported...',flush=True)
print('---------------',flush=True)
# Out:
# Dependencies imported...
# ---------------

# %% [markdown]
# # Inspections Data Download

# %%
url = 'https://services.arcgis.com/afSMGVsC7QlRK1kZ/arcgis/rest/services/Food_Inspections/FeatureServer/0/query?'
params = "where=FacilityCategory%20%3D%20%27RESTAURANT%27"
outfields = "&outFields=BusinessName,HealthFacilityIDNumber,FullAddress,Neighborhood,InspectionType,DateOfInspection,InspectionIDNumber,InspectionScore,Latitude,Longitude,ZipCode,FoodCodeText,ViolationPoints,InspectionResult,FoodCodeItem,InspectorComments,ViolationStatus,ViolationPriority&returnGeometry=false&outSR=4326"
json = '&f=json'

full_url = url+params+outfields+json

response = requests.get(full_url)

data=response.json()['features']

# %%
inspection_data_list = []

for records in data:
    item = records['attributes']
    item['DateOfInspection']=time.strftime('%Y/%m/%d',time.gmtime(records['attributes']['DateOfInspection']/1000))
    inspection_data_list.append(item)
    
print('inspection_data_list with needed data has been built.',flush=True)
print('---------------',flush=True)
# Out:
# inspection_data_list with needed data has been built.
# ---------------

# %%
inspections_df_base = pd.DataFrame(inspection_data_list)

inspections_df_1 = inspections_df_base[['InspectionIDNumber','DateOfInspection','BusinessName','FullAddress','Neighborhood','InspectionType','InspectionScore','Latitude','Longitude',"ZipCode"]]
inspections_df_1 = inspections_df_1.drop_duplicates(subset='InspectionIDNumber', keep='first')
inspections_df_1 = inspections_df_1.sort_values(by=['BusinessName','DateOfInspection'])
inspections_df_1 = inspections_df_1.rename(columns={'BusinessName':'inspect_name','FullAddress':'address','Neighborhood':'neighborhood','Latitude':'latitude','Longitude':'longitude','ZipCode':'zipcode','InspectionIDNumber':'inspectionidnumber','DateOfInspection':'dateofinspection','InspectionScore':'inspectionscore','InspectionType':'inspectiontype'})

inspections_detail = inspections_df_base[['DateOfInspection','InspectionIDNumber','BusinessName','FullAddress','InspectionType','InspectionScore','InspectionResult','FoodCodeItem','FoodCodeText','InspectorComments','ViolationPriority','ViolationStatus','ViolationPoints']]
inspections_detail = inspections_detail.sort_values(by=['BusinessName','DateOfInspection'])
inspections_detail = inspections_detail.rename(columns={'InspectionIDNumber':'inspectionidnumber','DateOfInspection':'dateofinspection','BusinessName':'businessname','FullAddress':'fulladdress','InspectionType':'inspectiontype','InspectionScore':'inspectionscore','InspectionResult':'inspectionresult','FoodCodeItem':'foodcodeitem','FoodCodeText':'foodcodetext','InspectorComments':'inspectorcomments','ViolationPriority':'violationpriority','ViolationStatus':'violationstatus','ViolationPoints':'violationpoints'})

print('Inspection Detail DataFrame now stored in memory as "inspection_detail"',flush=True)
print('---------------',flush=True)
# Out:
# Inspection Detail DataFrame now stored in memory as "inspection_detail"
# ---------------

# %%
grand_master_data=inspections_df_1.groupby(['inspect_name','address','zipcode','neighborhood','latitude','longitude'],sort=False,as_index=False).aggregate(lambda x: list(x))
grand_master_list = grand_master_data.to_dict('records')

for item in grand_master_list:
    currentDT=datetime.datetime.now()
    item.update(updated = currentDT.strftime("%a, %b %d, %Y at %I:%M %p"))

print('Inspections Dictionaries list now stored in memory as "grand_master_list"', flush=True)
print(f'There are {len(inspections_df_1)} inspections for {len(grand_master_list)} facilities.',flush=True)

print('---------------',flush=True)
# Out:
# Inspections Dictionaries list now stored in memory as "grand_master_list"
# There are 6184 inspections for 1536 facilities.
# ---------------

# %%
grand_master_list
# Out:
# [{'inspect_name': '112 EATERY',
#   'address': '112 3RD ST N',
#   'zipcode': '55401',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.98266,
#   'longitude': -93.27156,
#   'inspectionidnumber': [44334, 224449, 224448, 270458, 270457],
#   'dateofinspection': ['2017/08/31',
#    '2017/10/06',
#    '2018/08/31',
#    '2018/10/01',
#    '2019/08/30'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [80, 96, 84, 100, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '19 BAR',
#   'address': '19 15TH ST W',
#   'zipcode': '55403',
#   'neighborhood': 'Loring Park',
#   'latitude': 44.96745,
#   'longitude': -93.27883,
#   'inspectionidnumber': [44352, 193458],
#   'dateofinspection': ['2017/03/23', '2018/10/02'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [98, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '1ST CUP CAFE & RESTAURANT',
#   'address': '2740 MINNEHAHA AVE #180',
#   'zipcode': '55406',
#   'neighborhood': 'Longfellow',
#   'latitude': 44.95167,
#   'longitude': -93.23735,
#   'inspectionidnumber': [304218, 313672],
#   'dateofinspection': ['2019/06/14', '2019/07/17'],
#   'inspectiontype': ['Routine', 'Follow-Up'],
#   'inspectionscore': [84, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '1ST WOK LAKESIDE',
#   'address': '3236 LAKE ST W',
#   'zipcode': '55416',
#   'neighborhood': 'Cedar - Isles - Dean',
#   'latitude': 44.94913,
#   'longitude': -93.32083,
#   'inspectionidnumber': [44398, 228784, 228783, 276701, 276700],
#   'dateofinspection': ['2017/10/10',
#    '2017/12/12',
#    '2018/10/18',
#    '2018/11/27',
#    '2019/10/18'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [96, 100, 72, 96, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '331 CLUB',
#   'address': '331 13TH AVE NE',
#   'zipcode': '55413',
#   'neighborhood': 'Sheridan',
#   'latitude': 45.00121,
#   'longitude': -93.26287,
#   'inspectionidnumber': [44455, 189617, 237422, 237421, 287120, 286896],
#   'dateofinspection': ['2017/01/30',
#    '2017/12/18',
#    '2018/01/18',
#    '2018/12/31',
#    '2019/02/01',
#    '2019/12/31'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [96, 92, 100, 94, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '38TH ST DAIRY QUEEN',
#   'address': '3747 13TH AVE S',
#   'zipcode': '55407',
#   'neighborhood': 'Powderhorn Park',
#   'latitude': 44.9343,
#   'longitude': -93.25582,
#   'inspectionidnumber': [44484, 198040, 249069],
#   'dateofinspection': ['2017/05/10', '2018/05/04', '2019/05/16'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [92, 98, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '4 BELLS',
#   'address': '1610 HARMON PL',
#   'zipcode': '55403',
#   'neighborhood': 'Loring Park',
#   'latitude': 44.97172,
#   'longitude': -93.28552,
#   'inspectionidnumber': [44544, 200509, 200508, 252481, 252480, 313917],
#   'dateofinspection': ['2017/05/25',
#    '2017/06/30',
#    '2018/06/07',
#    '2018/07/12',
#    '2019/06/11',
#    '2019/07/09'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [92, 100, 90, 100, 84, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '5 CORNER MARKET',
#   'address': '2425 WEST BROADWAY',
#   'zipcode': '55411',
#   'neighborhood': 'Willard - Hay',
#   'latitude': 45.00577,
#   'longitude': -93.31175,
#   'inspectionidnumber': [315055],
#   'dateofinspection': ['2019/09/04'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '5 DOLLAR PIZZA',
#   'address': '137 FRANKLIN AVE E',
#   'zipcode': '55404',
#   'neighborhood': 'Whittier',
#   'latitude': 44.96248,
#   'longitude': -93.27437,
#   'inspectionidnumber': [280883],
#   'dateofinspection': ['2019/01/29'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '5-8 CLUB',
#   'address': '5800 CEDAR AVE S',
#   'zipcode': '55417',
#   'neighborhood': 'Diamond Lake',
#   'latitude': 44.89773,
#   'longitude': -93.248,
#   'inspectionidnumber': [44620, 229830, 229829, 277908, 277907],
#   'dateofinspection': ['2017/10/17',
#    '2017/12/14',
#    '2018/10/30',
#    '2018/11/29',
#    '2019/10/30'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [96, 98, 98, 98, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '5TH AVE MARKET',
#   'address': '201 5TH AVE N',
#   'zipcode': '55401',
#   'neighborhood': 'North Loop',
#   'latitude': 44.98635,
#   'longitude': -93.27342,
#   'inspectionidnumber': [44652, 181142, 237545, 286986, 287156],
#   'dateofinspection': ['2017/01/04',
#    '2018/01/12',
#    '2019/01/03',
#    '2019/02/13',
#    '2019/12/03'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [100, 100, 96, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '5TH STREET STATION',
#   'address': '416 5TH AVE N',
#   'zipcode': '55401',
#   'neighborhood': 'Marcy Holmes',
#   'latitude': 44.9859,
#   'longitude': -93.24746,
#   'inspectionidnumber': [316382],
#   'dateofinspection': ['2019/07/26'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '7 - THE SKYBAR',
#   'address': '700 HENNEPIN AVE',
#   'zipcode': '55403',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97801,
#   'longitude': -93.27548,
#   'inspectionidnumber': [44730, 196602, 249194],
#   'dateofinspection': ['2017/04/21', '2018/05/01', '2019/05/03'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '7 SEVEN',
#   'address': '700 HENNEPIN AVE',
#   'zipcode': '55403',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97801,
#   'longitude': -93.27548,
#   'inspectionidnumber': [44716,
#    192035,
#    249180,
#    253687,
#    258138,
#    249179,
#    310089,
#    313146],
#   'dateofinspection': ['2017/02/28',
#    '2018/05/01',
#    '2018/06/26',
#    '2018/07/25',
#    '2018/08/31',
#    '2019/05/03',
#    '2019/05/30',
#    '2019/06/27'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up'],
#   'inspectionscore': [94, 94, 94, 94, 92, 86, 86, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '801 CHOP HOUSE',
#   'address': '801 NICOLLET MALL',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97559,
#   'longitude': -93.2728,
#   'inspectionidnumber': [337401, 341655],
#   'dateofinspection': ['2020/01/16', '2020/01/29'],
#   'inspectiontype': ['Routine', 'Follow-Up'],
#   'inspectionscore': [76, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': '8TH STREET GRILL & TAVERN',
#   'address': '800 MARQUETTE AVE',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97559,
#   'longitude': -93.2728,
#   'inspectionidnumber': [44781, 200977, 200976, 251758, 310357],
#   'dateofinspection': ['2017/05/30',
#    '2017/07/12',
#    '2018/05/22',
#    '2019/05/14',
#    '2019/06/13'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [94, 100, 96, 90, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'A & J FISH & CHICKEN',
#   'address': '500 LAKE ST E',
#   'zipcode': '55408',
#   'neighborhood': 'Phillips West',
#   'latitude': 44.94859,
#   'longitude': -93.26869,
#   'inspectionidnumber': [44833, 228301, 228300, 274054, 274053, 330518],
#   'dateofinspection': ['2017/10/09',
#    '2017/11/09',
#    '2018/10/01',
#    '2018/11/01',
#    '2019/09/25',
#    '2019/11/07'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [86, 100, 88, 100, 70, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'A CUPCAKE SOCIAL',
#   'address': '3800 28TH AVE S',
#   'zipcode': '55406',
#   'neighborhood': 'Standish',
#   'latitude': 44.93395,
#   'longitude': -93.23234,
#   'inspectionidnumber': [44891, 191160, 245360, 245359],
#   'dateofinspection': ['2017/02/22', '2018/03/01', '2018/05/03', '2019/03/08'],
#   'inspectiontype': ['Routine', 'Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [96, 96, 100, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'A LA SALSA RESTAURANT',
#   'address': '920 LAKE ST E #155',
#   'zipcode': '55407',
#   'neighborhood': 'Midtown Phillips',
#   'latitude': 44.94931,
#   'longitude': -93.26076,
#   'inspectionidnumber': [32331, 191472, 243457, 299767, 355153],
#   'dateofinspection': ['2017/02/21',
#    '2018/02/20',
#    '2019/02/21',
#    '2020/02/12',
#    '2020/02/24'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine', 'Routine', 'Follow-Up'],
#   'inspectionscore': [100, 98, 94, 84, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'A SLICE OF NEW YORK',
#   'address': '2407 NICOLLET AVE',
#   'zipcode': '55404',
#   'neighborhood': 'Whittier',
#   'latitude': 44.95892,
#   'longitude': -93.27745,
#   'inspectionidnumber': [51319, 201078, 201077, 251943, 251942, 313461],
#   'dateofinspection': ['2017/06/06',
#    '2017/07/13',
#    '2018/06/04',
#    '2018/07/24',
#    '2019/06/06',
#    '2019/07/24'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [86, 100, 90, 96, 90, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AARAN RESTAURANT',
#   'address': '2910 PILLSBURY AVE',
#   'zipcode': '55408',
#   'neighborhood': 'Whittier',
#   'latitude': 44.94969,
#   'longitude': -93.2821,
#   'inspectionidnumber': [274005, 286257, 286256],
#   'dateofinspection': ['2018/12/20', '2019/02/01', '2019/12/26'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [82, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ABBOTT NORTHWESTERN HOSPITAL',
#   'address': '800 28TH ST E',
#   'zipcode': '55407',
#   'neighborhood': 'Midtown Phillips',
#   'latitude': 44.95458,
#   'longitude': -93.26133,
#   'inspectionidnumber': [51355, 195001, 195000, 247588, 247587],
#   'dateofinspection': ['2017/04/05',
#    '2017/05/04',
#    '2018/04/09',
#    '2018/05/08',
#    '2019/04/11'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [92, 98, 92, 96, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "ABI'S CAFE",
#   'address': '1532 LAKE ST E',
#   'zipcode': '55407',
#   'neighborhood': 'East Phillips',
#   'latitude': 44.94865,
#   'longitude': -93.25206,
#   'inspectionidnumber': [51412, 203606, 203605, 263812, 263811, 322493],
#   'dateofinspection': ['2017/07/08',
#    '2017/08/28',
#    '2018/08/08',
#    '2018/08/28',
#    '2019/08/07',
#    '2019/09/04'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [98, 100, 94, 100, 80, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AC HOTEL MINNEAPOLIS DOWNTOWN',
#   'address': '401 HENNEPIN AVE',
#   'zipcode': '55401',
#   'neighborhood': 'Nicollet Island - East Bank',
#   'latitude': 44.9888,
#   'longitude': -93.25494,
#   'inspectionidnumber': [124347, 233758, 279995, 337879],
#   'dateofinspection': ['2017/11/21', '2018/11/21', '2019/11/26', '2019/12/27'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine', 'Follow-Up'],
#   'inspectionscore': [100, 100, 88, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ACADIA CAFE',
#   'address': '329 CEDAR AVE S',
#   'zipcode': '55454',
#   'neighborhood': 'Cedar Riverside',
#   'latitude': 44.97027,
#   'longitude': -93.24694,
#   'inspectionidnumber': [51453, 232244, 232243, 278698, 278697, 336675],
#   'dateofinspection': ['2017/11/01',
#    '2017/12/11',
#    '2018/11/01',
#    '2018/12/06',
#    '2019/11/04',
#    '2019/12/12'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [84, 100, 96, 100, 86, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ADELITAS MEXICAN RESTAURANT',
#   'address': '2405 CENTRAL AVE NE',
#   'zipcode': '55418',
#   'neighborhood': 'Windom Park',
#   'latitude': 45.01243,
#   'longitude': -93.24694,
#   'inspectionidnumber': [124215, 124214, 232693, 232692, 278430, 336509],
#   'dateofinspection': ['2017/04/27',
#    '2017/11/03',
#    '2017/12/15',
#    '2018/10/25',
#    '2019/10/25',
#    '2019/12/06'],
#   'inspectiontype': ['Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [100, 96, 100, 92, 88, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AFC SUSHI @ KOWALSKIS #5366',
#   'address': '2440 HENNEPIN AVE',
#   'zipcode': '55405',
#   'neighborhood': 'East Isles',
#   'latitude': 44.95767,
#   'longitude': -93.29608,
#   'inspectionidnumber': [180494, 241935, 295094],
#   'dateofinspection': ['2018/01/09', '2019/01/09', '2020/01/07'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 96, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AFC SUSHI @ KOWALSKIS #5368',
#   'address': '5327 LYNDALE AVE S',
#   'zipcode': '55419',
#   'neighborhood': 'Tangletown',
#   'latitude': 44.90559,
#   'longitude': -93.28761,
#   'inspectionidnumber': [51560, 202380, 253340],
#   'dateofinspection': ['2017/06/22', '2018/06/25', '2019/06/20'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [98, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AFRO DELI & GRILL',
#   'address': '733 MARQUETTE AVE',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97555,
#   'longitude': -93.271,
#   'inspectionidnumber': [332536, 338549],
#   'dateofinspection': ['2019/12/09', '2020/01/06'],
#   'inspectiontype': ['Routine', 'Follow-Up'],
#   'inspectionscore': [90, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AFRO DELI AND COFFEE LLC',
#   'address': '720 WASHINGTON AVE SE',
#   'zipcode': '55414',
#   'neighborhood': 'University of Minnesota',
#   'latitude': 44.97333,
#   'longitude': -93.22759,
#   'inspectionidnumber': [191908, 197629, 249117, 253691, 249116],
#   'dateofinspection': ['2017/05/03',
#    '2018/05/02',
#    '2018/06/29',
#    '2018/08/10',
#    '2019/05/01'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [94, 80, 90, 100, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AGRA CULTURE',
#   'address': '3717 50TH ST W',
#   'zipcode': '55410',
#   'neighborhood': 'Fulton',
#   'latitude': 44.91218,
#   'longitude': -93.3274,
#   'inspectionidnumber': [51862, 181245, 51863, 228030, 236466, 281362, 281361],
#   'dateofinspection': ['2017/01/04',
#    '2017/02/22',
#    '2017/10/04',
#    '2017/11/07',
#    '2018/12/11',
#    '2019/02/12',
#    '2020/01/02'],
#   'inspectiontype': ['Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [94, 96, 76, 88, 90, 98, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AGRA CULTURE',
#   'address': '2400 3RD AVE S',
#   'zipcode': '55404',
#   'neighborhood': 'Whittier',
#   'latitude': 44.95821,
#   'longitude': -93.27404,
#   'inspectionidnumber': [51859, 188599, 237554, 237553, 287838],
#   'dateofinspection': ['2017/01/19',
#    '2018/01/09',
#    '2018/03/08',
#    '2019/01/15',
#    '2020/01/15'],
#   'inspectiontype': ['Routine', 'Routine', 'Follow-Up', 'Routine', 'Routine'],
#   'inspectionscore': [96, 86, 92, 94, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AGRA CULTURE',
#   'address': '2939 GIRARD AVE S',
#   'zipcode': '55408',
#   'neighborhood': 'Lowry Hill East',
#   'latitude': 44.94885,
#   'longitude': -93.29663,
#   'inspectionidnumber': [11079, 242989, 291219],
#   'dateofinspection': ['2017/10/28', '2019/01/15', '2020/01/09'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 96, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AH SA WAN',
#   'address': '121 8TH ST S #TCF TOWER',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97441,
#   'longitude': -93.27109,
#   'inspectionidnumber': [51905, 224895, 272107],
#   'dateofinspection': ['2017/09/07', '2018/09/12', '2019/08/28'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [96, 100, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AHLAN RESTAURANT',
#   'address': '2401 FRANKLIN AVE E',
#   'zipcode': '55406',
#   'neighborhood': 'Seward',
#   'latitude': 44.96248,
#   'longitude': -93.23747,
#   'inspectionidnumber': [329054, 337393, 340522],
#   'dateofinspection': ['2019/11/08', '2020/01/09', '2020/01/23'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Follow-Up'],
#   'inspectionscore': [84, 84, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AKIS BREAD HAUS',
#   'address': '2506 CENTRAL AVE NE',
#   'zipcode': '55418',
#   'neighborhood': 'Holland',
#   'latitude': 45.01356,
#   'longitude': -93.24788,
#   'inspectionidnumber': [51989, 205351, 259438],
#   'dateofinspection': ['2017/07/06', '2018/07/23', '2019/07/18'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [96, 96, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AKWAABA',
#   'address': '1823 NICOLLET AVE',
#   'zipcode': '55403',
#   'neighborhood': "Steven's Square - Loring Heights",
#   'latitude': 44.96459,
#   'longitude': -93.27744,
#   'inspectionidnumber': [52038, 197554, 197553, 247742],
#   'dateofinspection': ['2017/04/28', '2017/06/29', '2018/04/10', '2019/04/15'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine', 'Routine'],
#   'inspectionscore': [98, 100, 98, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ALL SQUARE',
#   'address': '4047 MINNEHAHA AVE',
#   'zipcode': '55406',
#   'neighborhood': 'Hiawatha',
#   'latitude': 44.92893,
#   'longitude': -93.2196,
#   'inspectionidnumber': [270812, 280351],
#   'dateofinspection': ['2018/11/27', '2019/11/27'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [94, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ALLE AAMIN COFFEE SHOP',
#   'address': '609 CEDAR AVE S',
#   'zipcode': '55454',
#   'neighborhood': 'Cedar Riverside',
#   'latitude': 44.96738,
#   'longitude': -93.24687,
#   'inspectionidnumber': [59125, 213894, 213893, 265721, 265720, 325066],
#   'dateofinspection': ['2017/08/04',
#    '2017/10/24',
#    '2018/08/15',
#    '2018/10/11',
#    '2019/08/15',
#    '2019/10/09'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [80, 100, 82, 98, 88, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ALLIES RAND DELI & CATERING',
#   'address': '527 MARQUETTE AVE',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97733,
#   'longitude': -93.26956,
#   'inspectionidnumber': [59158, 228216, 228215, 275134, 275133],
#   'dateofinspection': ['2017/10/06',
#    '2017/11/06',
#    '2018/10/09',
#    '2018/12/06',
#    '2019/10/09'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [88, 100, 90, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ALOFT HOTEL MINNEAPOLIS',
#   'address': '900 WASHINGTON AVE S',
#   'zipcode': '55415',
#   'neighborhood': 'Downtown East',
#   'latitude': 44.97659,
#   'longitude': -93.25502,
#   'inspectionidnumber': [59226, 194020, 246855, 246854],
#   'dateofinspection': ['2017/03/21', '2018/03/27', '2018/07/11', '2019/03/26'],
#   'inspectiontype': ['Routine', 'Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [100, 86, 96, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ALOHA POKE CO',
#   'address': '811 LASALLE AVE',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97592,
#   'longitude': -93.27444,
#   'inspectionidnumber': [246581, 251402, 251401],
#   'dateofinspection': ['2018/05/21', '2018/06/14', '2019/05/07'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [88, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ALS BREAKFAST',
#   'address': '413 14TH AVE SE',
#   'zipcode': '55414',
#   'neighborhood': 'Marcy Holmes',
#   'latitude': 44.98101,
#   'longitude': -93.23569,
#   'inspectionidnumber': [59243,
#    201208,
#    205347,
#    201207,
#    252901,
#    252900,
#    314465],
#   'dateofinspection': ['2017/06/02',
#    '2017/07/18',
#    '2017/09/20',
#    '2018/06/18',
#    '2018/08/01',
#    '2019/06/18',
#    '2019/07/23'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [80, 92, 98, 90, 96, 90, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AMAZING THAILAND',
#   'address': '3024 HENNEPIN AVE',
#   'zipcode': '55408',
#   'neighborhood': 'ECCO',
#   'latitude': 44.94744,
#   'longitude': -93.29867,
#   'inspectionidnumber': [59348,
#    229841,
#    236553,
#    242956,
#    229840,
#    276983,
#    276982],
#   'dateofinspection': ['2017/10/13',
#    '2017/12/19',
#    '2018/02/12',
#    '2018/03/21',
#    '2018/10/19',
#    '2018/11/30',
#    '2019/10/31'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [82, 90, 90, 100, 88, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AMERICAN LEGION',
#   'address': '5600 34TH AVE S',
#   'zipcode': '55417',
#   'neighborhood': 'Wenonah',
#   'latitude': 44.90155,
#   'longitude': -93.22334,
#   'inspectionidnumber': [59408, 240981, 240503],
#   'dateofinspection': ['2018/01/17', '2018/02/28', '2019/07/23'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [90, 92, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AMERICAN LEGION DEPT OF MINNESOTA',
#   'address': '3751 MINNEHAHA AVE',
#   'zipcode': '55406',
#   'neighborhood': 'Howe',
#   'latitude': 44.93452,
#   'longitude': -93.22357,
#   'inspectionidnumber': [59437, 276649],
#   'dateofinspection': ['2018/10/17', '2018/12/13'],
#   'inspectiontype': ['Routine', 'Follow-Up'],
#   'inspectionscore': [88, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AMERICAN LEGION POST #99',
#   'address': '5600 34TH AVE S',
#   'zipcode': '55417',
#   'neighborhood': 'Wenonah',
#   'latitude': 44.90155,
#   'longitude': -93.22334,
#   'inspectionidnumber': [59457, 240972, 240971],
#   'dateofinspection': ['2018/01/17', '2018/02/28', '2019/07/23'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [90, 92, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AMORE UPTOWN',
#   'address': '1601 LAKE ST W',
#   'zipcode': '55408',
#   'neighborhood': 'ECCO',
#   'latitude': 44.94807,
#   'longitude': -93.30246,
#   'inspectionidnumber': [10452,
#    10453,
#    223052,
#    230519,
#    223051,
#    271524,
#    277706,
#    271523],
#   'dateofinspection': ['2017/01/26',
#    '2017/08/23',
#    '2017/10/19',
#    '2017/12/22',
#    '2018/09/07',
#    '2018/10/26',
#    '2018/12/21',
#    '2019/09/06'],
#   'inspectiontype': ['Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [96, 86, 94, 100, 92, 98, 98, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ANDREA PIZZA',
#   'address': '225 6TH ST S #A203',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.976,
#   'longitude': -93.26826,
#   'inspectionidnumber': [10625, 203029, 203028, 254564],
#   'dateofinspection': ['2017/06/29', '2017/07/17', '2018/07/12', '2019/07/01'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine', 'Routine'],
#   'inspectionscore': [92, 100, 98, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ANDREA PIZZA',
#   'address': '811 LASALLE AVE #SUITE 202',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97592,
#   'longitude': -93.27444,
#   'inspectionidnumber': [10606, 204007, 290814],
#   'dateofinspection': ['2017/07/12', '2019/01/16', '2019/02/14'],
#   'inspectiontype': ['Routine', 'Routine', 'Follow-Up'],
#   'inspectionscore': [96, 88, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "ANDREA'S PIZZA",
#   'address': '330 2ND AVE S #214',
#   'zipcode': '55401',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97927,
#   'longitude': -93.26702,
#   'inspectionidnumber': [10636, 180909, 242249, 291044],
#   'dateofinspection': ['2017/01/03', '2018/02/06', '2019/01/03', '2019/12/26'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine', 'Routine'],
#   'inspectionscore': [96, 100, 98, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "ANDY'S DINER",
#   'address': '1500 LAKE ST W',
#   'zipcode': '55408',
#   'neighborhood': 'East Isles',
#   'latitude': 44.94865,
#   'longitude': -93.30103,
#   'inspectionidnumber': [338810],
#   'dateofinspection': ['2020/02/19'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "ANDY'S GARAGE",
#   'address': '920 LAKE ST E #151',
#   'zipcode': '55407',
#   'neighborhood': 'Midtown Phillips',
#   'latitude': 44.94931,
#   'longitude': -93.26076,
#   'inspectionidnumber': [10664, 191983, 243469, 297578, 354021],
#   'dateofinspection': ['2017/02/27',
#    '2018/02/21',
#    '2019/02/07',
#    '2020/02/06',
#    '2020/02/13'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine', 'Routine', 'Follow-Up'],
#   'inspectionscore': [100, 94, 100, 80, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ANELACE COFFEE',
#   'address': '2402 CENTRAL AVE NE',
#   'zipcode': '55418',
#   'neighborhood': 'Holland',
#   'latitude': 45.01243,
#   'longitude': -93.24788,
#   'inspectionidnumber': [10668, 201834, 253195, 253194],
#   'dateofinspection': ['2017/06/16', '2018/06/14', '2018/08/10', '2019/06/14'],
#   'inspectiontype': ['Routine', 'Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [100, 90, 100, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ANGEL FOOD',
#   'address': '86 9TH ST S',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97482,
#   'longitude': -93.27267,
#   'inspectionidnumber': [10687, 223945, 302232],
#   'dateofinspection': ['2017/08/31', '2019/02/26', '2019/03/13'],
#   'inspectiontype': ['Routine', 'Routine', 'Follow-Up'],
#   'inspectionscore': [94, 88, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ANGRY CATFISH BICYCLE',
#   'address': '4208 28TH AVE S',
#   'zipcode': '55406',
#   'neighborhood': 'Standish',
#   'latitude': 44.92652,
#   'longitude': -93.2325,
#   'inspectionidnumber': [10700, 194634, 307135],
#   'dateofinspection': ['2017/04/06', '2019/03/26', '2019/05/21'],
#   'inspectiontype': ['Routine', 'Routine', 'Follow-Up'],
#   'inspectionscore': [100, 88, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ANNIES KITTY CAT KLUB',
#   'address': '313 14TH AVE SE',
#   'zipcode': '55414',
#   'neighborhood': 'Marcy Holmes',
#   'latitude': 44.98005,
#   'longitude': -93.23656,
#   'inspectionidnumber': [10746,
#    188756,
#    242341,
#    242340,
#    294190,
#    294189,
#    353704],
#   'dateofinspection': ['2017/01/12',
#    '2018/02/07',
#    '2018/03/14',
#    '2019/01/29',
#    '2019/03/20',
#    '2020/01/29',
#    '2020/02/27'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [100, 94, 100, 90, 96, 84, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ANTRO BAR',
#   'address': '419 LAKE ST E',
#   'zipcode': '55408',
#   'neighborhood': 'Central',
#   'latitude': 44.94779,
#   'longitude': -93.26942,
#   'inspectionidnumber': [280886, 294805],
#   'dateofinspection': ['2019/02/01', '2020/01/31'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [98, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'APOTHICARE',
#   'address': '3722 CHICAGO AVE',
#   'zipcode': '55407',
#   'neighborhood': 'Central',
#   'latitude': 44.93505,
#   'longitude': -93.26289,
#   'inspectionidnumber': [267122],
#   'dateofinspection': ['2018/10/22'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'APOY',
#   'address': '4301 NICOLLET AVE',
#   'zipcode': '55409',
#   'neighborhood': 'King Field',
#   'latitude': 44.92488,
#   'longitude': -93.27754,
#   'inspectionidnumber': [280884, 304779],
#   'dateofinspection': ['2019/03/06', '2020/02/27'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [100, 82],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'APPLE SPICE',
#   'address': '740 HARDING ST NE',
#   'zipcode': '55413',
#   'neighborhood': 'Mid - City Industrial',
#   'latitude': 44.9974,
#   'longitude': -93.22234,
#   'inspectionidnumber': [272025, 280091, 280090],
#   'dateofinspection': ['2018/11/21', '2019/01/04', '2019/11/22'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [88, 94, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "APPLEBEE'S NEIGHBORHOOD GRILL & BAR",
#   'address': '615 WASHINGTON AVE SE',
#   'zipcode': '55414',
#   'neighborhood': 'University of Minnesota',
#   'latitude': 44.97419,
#   'longitude': -93.22952,
#   'inspectionidnumber': [10859, 227606, 275288],
#   'dateofinspection': ['2017/10/04', '2018/10/11', '2019/09/27'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ARBYS #1919',
#   'address': '3000 SNELLING AVE',
#   'zipcode': '55406',
#   'neighborhood': 'Longfellow',
#   'latitude': 44.9479,
#   'longitude': -93.23627,
#   'inspectionidnumber': [10988, 200842],
#   'dateofinspection': ['2017/06/06', '2018/12/27'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [96, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AREA CONCESSIONS',
#   'address': '600 KENWOOD PKWY',
#   'zipcode': '55403',
#   'neighborhood': 'Lowry Hill',
#   'latitude': 44.97083,
#   'longitude': -93.29497,
#   'inspectionidnumber': [325140],
#   'dateofinspection': ['2019/10/05'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AREZZO RISTORANTE',
#   'address': '5057 FRANCE AVE S',
#   'zipcode': '55410',
#   'neighborhood': 'Fulton',
#   'latitude': 44.91098,
#   'longitude': -93.32866,
#   'inspectionidnumber': [11054, 228738, 236557, 228737, 277679, 277678],
#   'dateofinspection': ['2017/10/11',
#    '2017/12/20',
#    '2018/02/14',
#    '2018/10/26',
#    '2018/11/30',
#    '2019/11/07'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [84, 98, 100, 88, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ARIA AT THE JEUNE LUNE',
#   'address': '105 1ST ST N',
#   'zipcode': '55401',
#   'neighborhood': 'North Loop',
#   'latitude': 44.98471,
#   'longitude': -93.26873,
#   'inspectionidnumber': [11086, 198067, 249338],
#   'dateofinspection': ['2017/05/10', '2018/05/03', '2019/05/04'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "ASA'S BALERY",
#   'address': '3507 23RD AVE S',
#   'zipcode': '55407',
#   'neighborhood': 'Corcoran',
#   'latitude': 44.93929,
#   'longitude': -93.23867,
#   'inspectionidnumber': [337849],
#   'dateofinspection': ['2020/01/24'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ASIAN AVENUE',
#   'address': '3060 EXCELSIOR BLVD',
#   'zipcode': '55416',
#   'neighborhood': 'West Calhoun',
#   'latitude': 44.94759,
#   'longitude': -93.32256,
#   'inspectionidnumber': [18096, 204671, 204670, 259655],
#   'dateofinspection': ['2017/07/13', '2017/09/05', '2018/07/27', '2019/07/26'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine', 'Routine'],
#   'inspectionscore': [92, 100, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ASIAN MAX',
#   'address': '120 6TH ST S #215',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97736,
#   'longitude': -93.26875,
#   'inspectionidnumber': [304537],
#   'dateofinspection': ['2020/01/15'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ASTER CAFE',
#   'address': '125 MAIN ST SE',
#   'zipcode': '55414',
#   'neighborhood': 'Marcy Holmes',
#   'latitude': 44.98467,
#   'longitude': -93.25494,
#   'inspectionidnumber': [18200, 191230, 243835, 303493],
#   'dateofinspection': ['2017/02/23', '2018/02/27', '2019/03/04', '2019/04/10'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine', 'Follow-Up'],
#   'inspectionscore': [100, 100, 86, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ATLAS RESTAURANT',
#   'address': '200 6TH ST S #175',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.9769,
#   'longitude': -93.26762,
#   'inspectionidnumber': [18222,
#    190055,
#    190054,
#    243459,
#    243458,
#    298700,
#    307946,
#    298699,
#    354936],
#   'dateofinspection': ['2017/02/07',
#    '2017/03/08',
#    '2018/02/14',
#    '2018/03/19',
#    '2019/02/13',
#    '2019/04/10',
#    '2019/05/15',
#    '2020/02/12',
#    '2020/02/26'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [87, 96, 84, 100, 76, 92, 100, 90, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AUGIES CABARET',
#   'address': '424 HENNEPIN AVE',
#   'zipcode': '55401',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97994,
#   'longitude': -93.27258,
#   'inspectionidnumber': [18318],
#   'dateofinspection': ['2018/10/02'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AUGSBURG COLLEGE',
#   'address': '2211 RIVERSIDE AVE',
#   'zipcode': '55454',
#   'neighborhood': 'Cedar Riverside',
#   'latitude': 44.96561,
#   'longitude': -93.24177,
#   'inspectionidnumber': [18324, 232562],
#   'dateofinspection': ['2017/11/08', '2019/11/15'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AUGUSTANA  APARTMENTS',
#   'address': '1510 11TH AVE S',
#   'zipcode': '55404',
#   'neighborhood': 'Elliot Park',
#   'latitude': 44.96762,
#   'longitude': -93.2586,
#   'inspectionidnumber': [18382, 194013, 246885],
#   'dateofinspection': ['2017/03/14', '2018/03/15', '2019/03/19'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 96, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'AUGUSTANA COMMUNITY PARTNERS',
#   'address': '350 VAN WHITE MEMORIAL BLVD',
#   'zipcode': '55405',
#   'neighborhood': 'Sumner - Glenwood',
#   'latitude': 44.98128,
#   'longitude': -93.29408,
#   'inspectionidnumber': [180806, 231709, 279764],
#   'dateofinspection': ['2017/10/26', '2018/11/19', '2019/11/19'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [98, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'B-DUBS EXPRESS',
#   'address': '1221 LAKE ST W',
#   'zipcode': '55408',
#   'neighborhood': 'South Uptown',
#   'latitude': 44.94814,
#   'longitude': -93.2951,
#   'inspectionidnumber': [259507, 275863],
#   'dateofinspection': ['2018/10/16', '2019/10/16'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAARAKALLAH RESTAURANT',
#   'address': '408 CEDAR AVE S',
#   'zipcode': '55454',
#   'neighborhood': 'Cedar Riverside',
#   'latitude': 44.96989,
#   'longitude': -93.24761,
#   'inspectionidnumber': [243297, 251472, 299106, 299105, 355377],
#   'dateofinspection': ['2018/02/24',
#    '2019/02/19',
#    '2019/03/28',
#    '2020/02/12',
#    '2020/02/17'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [100, 80, 100, 84, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BACON SOCIAL HOUSE',
#   'address': '700 3RD ST S',
#   'zipcode': '55415',
#   'neighborhood': 'Downtown East',
#   'latitude': 44.97681,
#   'longitude': -93.2588,
#   'inspectionidnumber': [316212],
#   'dateofinspection': ['2019/09/17'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAD AXE THROWING',
#   'address': '2505 KENNEDY ST NE',
#   'zipcode': '55413',
#   'neighborhood': 'Mid - City Industrial',
#   'latitude': 44.99564,
#   'longitude': -93.22465,
#   'inspectionidnumber': [318691, 331977],
#   'dateofinspection': ['2019/10/06', '2019/11/17'],
#   'inspectiontype': ['Routine', 'Follow-Up'],
#   'inspectionscore': [84, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAD WAITRESS',
#   'address': '2 26TH ST E #C101',
#   'zipcode': '55404',
#   'neighborhood': 'Whittier',
#   'latitude': 44.95573,
#   'longitude': -93.27723,
#   'inspectionidnumber': [24821, 214877, 263818],
#   'dateofinspection': ['2017/08/09', '2018/08/08', '2019/08/08'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [96, 100, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAGU SUSHI AND THAI',
#   'address': '4741 CHICAGO AVE',
#   'zipcode': '55407',
#   'neighborhood': 'Northrop',
#   'latitude': 44.91632,
#   'longitude': -93.26224,
#   'inspectionidnumber': [249152,
#    249187,
#    254167,
#    270236,
#    278865,
#    287130,
#    249186,
#    314664,
#    337693],
#   'dateofinspection': ['2018/05/07',
#    '2018/07/09',
#    '2018/08/30',
#    '2018/10/29',
#    '2018/12/27',
#    '2019/05/17',
#    '2019/06/17',
#    '2019/11/21',
#    '2019/12/05'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up'],
#   'inspectionscore': [74, 84, 88, 94, 94, 98, 82, 84, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAHN APPETIT',
#   'address': '511 14TH AVE SE',
#   'zipcode': '55414',
#   'neighborhood': 'Marcy Holmes',
#   'latitude': 44.98232,
#   'longitude': -93.2356,
#   'inspectionidnumber': [330476],
#   'dateofinspection': ['2020/01/21'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "BAKER'S WIFE",
#   'address': '4200 28TH AVE S',
#   'zipcode': '55406',
#   'neighborhood': 'Standish',
#   'latitude': 44.92668,
#   'longitude': -93.23249,
#   'inspectionidnumber': [180589,
#    191067,
#    24975,
#    233051,
#    236905,
#    233050,
#    279502,
#    287160,
#    279501,
#    337501],
#   'dateofinspection': ['2017/02/17',
#    '2017/05/02',
#    '2017/10/31',
#    '2017/12/28',
#    '2018/02/14',
#    '2018/11/13',
#    '2019/01/11',
#    '2019/02/22',
#    '2019/11/13',
#    '2020/01/09'],
#   'inspectiontype': ['Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [92, 96, 86, 90, 92, 80, 88, 96, 82, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAMBOO GARDEN',
#   'address': '608 2ND AVE S #116',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97664,
#   'longitude': -93.26943,
#   'inspectionidnumber': [25061, 211861, 211860, 265336, 265335],
#   'dateofinspection': ['2017/08/03',
#    '2017/10/05',
#    '2018/08/15',
#    '2018/10/02',
#    '2019/08/15'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [96, 98, 92, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAMBU DESSERT DRINKS',
#   'address': '2743 NICOLLET AVE',
#   'zipcode': '55408',
#   'neighborhood': 'Whittier',
#   'latitude': 44.95224,
#   'longitude': -93.2775,
#   'inspectionidnumber': [25071, 228693, 228692, 275809],
#   'dateofinspection': ['2017/10/10', '2017/11/16', '2018/10/11', '2019/10/09'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine', 'Routine'],
#   'inspectionscore': [90, 100, 98, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "BAMINI'S COFFEE",
#   'address': '2414 7TH ST S',
#   'zipcode': '55454',
#   'neighborhood': 'Cedar Riverside',
#   'latitude': 44.9675,
#   'longitude': -93.23691,
#   'inspectionidnumber': [232268, 232341, 277007],
#   'dateofinspection': ['2017/10/24', '2018/10/23', '2019/10/25'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [96, 96, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BANANA BLOSSOM',
#   'address': '1724 LOWRY AVE N',
#   'zipcode': '55411',
#   'neighborhood': 'Folwell',
#   'latitude': 45.01346,
#   'longitude': -93.30162,
#   'inspectionidnumber': [25177,
#    196462,
#    200895,
#    196461,
#    249097,
#    249096,
#    310485],
#   'dateofinspection': ['2017/04/14',
#    '2017/06/06',
#    '2017/08/15',
#    '2018/05/01',
#    '2018/06/06',
#    '2019/05/14',
#    '2019/06/25'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [62, 86, 100, 90, 96, 84, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAND BOX',
#   'address': '729 10TH ST S',
#   'zipcode': '55404',
#   'neighborhood': 'Elliot Park',
#   'latitude': 44.96905,
#   'longitude': -93.26345,
#   'inspectionidnumber': [25203, 231247, 231246, 277628, 335734],
#   'dateofinspection': ['2017/10/17',
#    '2017/11/15',
#    '2018/10/17',
#    '2019/10/17',
#    '2019/11/18'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [90, 100, 90, 88, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BANGKOK MARKET & VIDEO RENTAL',
#   'address': '3100 LYNDALE AVE N',
#   'zipcode': '55411',
#   'neighborhood': 'Hawthorne',
#   'latitude': 45.01224,
#   'longitude': -93.28759,
#   'inspectionidnumber': [181006, 232660, 279659, 281507, 279658],
#   'dateofinspection': ['2017/11/09',
#    '2018/11/15',
#    '2018/12/14',
#    '2019/01/15',
#    '2019/11/08'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [100, 90, 90, 98, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAR BRAVA',
#   'address': '1914 WASHINGTON AVE N',
#   'zipcode': '55411',
#   'neighborhood': 'Near - North',
#   'latitude': 44.99867,
#   'longitude': -93.28137,
#   'inspectionidnumber': [336280, 339983],
#   'dateofinspection': ['2019/12/27', '2020/01/23'],
#   'inspectiontype': ['Routine', 'Follow-Up'],
#   'inspectionscore': [82, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAR LA GRASSA',
#   'address': '800 WASHINGTON AVE N #102',
#   'zipcode': '55401',
#   'neighborhood': 'North Loop',
#   'latitude': 44.98953,
#   'longitude': -93.27869,
#   'inspectionidnumber': [25271, 216880, 262751, 262750],
#   'dateofinspection': ['2017/08/10', '2018/08/07', '2018/09/12', '2019/08/21'],
#   'inspectiontype': ['Routine', 'Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [92, 82, 94, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAR LUCHADOR',
#   'address': '825 WASHINGTON AVE SE',
#   'zipcode': '55414',
#   'neighborhood': 'Prospect Park - East River Road',
#   'latitude': 44.97405,
#   'longitude': -93.22603,
#   'inspectionidnumber': [25295, 203240, 203239, 253422, 253421, 314505],
#   'dateofinspection': ['2017/06/29',
#    '2017/07/25',
#    '2018/06/25',
#    '2018/07/24',
#    '2019/06/25',
#    '2019/07/24'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [78, 100, 90, 96, 90, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BAR ZIA',
#   'address': '420 4TH ST S',
#   'zipcode': '55415',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.9776,
#   'longitude': -93.26297,
#   'inspectionidnumber': [124638, 236550, 236549, 286204, 286203, 341606],
#   'dateofinspection': ['2017/12/20',
#    '2018/02/12',
#    '2018/12/20',
#    '2019/01/25',
#    '2020/01/14',
#    '2020/01/30'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [86, 94, 94, 96, 72, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BARBETTE',
#   'address': '1600 LAKE ST W',
#   'zipcode': '55408',
#   'neighborhood': 'East Phillips',
#   'latitude': 44.94863,
#   'longitude': -93.25104,
#   'inspectionidnumber': [25354,
#    193285,
#    197611,
#    201956,
#    193284,
#    246658,
#    249265,
#    253160,
#    264612,
#    272873,
#    279768,
#    246657,
#    307528],
#   'dateofinspection': ['2017/03/06',
#    '2017/05/01',
#    '2017/06/19',
#    '2017/08/16',
#    '2018/03/14',
#    '2018/05/08',
#    '2018/06/15',
#    '2018/08/08',
#    '2018/09/18',
#    '2018/11/13',
#    '2019/01/25',
#    '2019/03/29',
#    '2019/05/16'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [90, 92, 96, 100, 64, 90, 94, 94, 92, 94, 100, 94, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BARDO',
#   'address': '222 HENNEPIN AVE E',
#   'zipcode': '55414',
#   'neighborhood': 'Nicollet Island - East Bank',
#   'latitude': 44.98746,
#   'longitude': -93.25676,
#   'inspectionidnumber': [230162, 241162, 241161, 292965, 292964, 352259],
#   'dateofinspection': ['2018/01/04',
#    '2018/04/06',
#    '2019/01/17',
#    '2019/03/14',
#    '2020/01/22',
#    '2020/02/20'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [80, 100, 80, 94, 86, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BARFLY',
#   'address': '711 HENNEPIN AVE',
#   'zipcode': '55403',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97743,
#   'longitude': -93.27489,
#   'inspectionidnumber': [125789, 241609],
#   'dateofinspection': ['2018/01/10', '2019/01/24'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [96, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BARRIO',
#   'address': '925 NICOLLET MALL',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.9742,
#   'longitude': -93.27408,
#   'inspectionidnumber': [30763, 202115, 202114, 253977, 253976, 314336],
#   'dateofinspection': ['2017/06/19',
#    '2017/07/14',
#    '2018/06/22',
#    '2018/07/25',
#    '2019/06/25',
#    '2019/07/22'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [80, 96, 90, 96, 82, 86],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BARWAQO RESTAURANT',
#   'address': '2820 13TH AVE S',
#   'zipcode': '55407',
#   'neighborhood': 'Midtown Phillips',
#   'latitude': 44.95073,
#   'longitude': -93.25693,
#   'inspectionidnumber': [233148, 242539, 242538, 294169, 294168, 350184],
#   'dateofinspection': ['2018/01/29',
#    '2018/02/24',
#    '2019/01/22',
#    '2019/02/13',
#    '2020/01/23',
#    '2020/02/12'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [90, 100, 92, 100, 90, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'BEANCOUNTER COFFEEHOUSE',
#   'address': '101 5TH ST S',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
# ...
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NILE RIVER CAFE',
#   'address': '2833 13TH AVE S #134',
#   'zipcode': '55407',
#   'neighborhood': 'Midtown Phillips',
#   'latitude': 44.95078,
#   'longitude': -93.25592,
#   'inspectionidnumber': [48587, 219085, 270732],
#   'dateofinspection': ['2017/08/19', '2018/09/06', '2019/09/03'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NOGOB COFFEE SHOP',
#   'address': '912 24TH ST E #B133',
#   'zipcode': '55404',
#   'neighborhood': 'Ventura Village',
#   'latitude': 44.95968,
#   'longitude': -93.26037,
#   'inspectionidnumber': [48651, 190338, 242426],
#   'dateofinspection': ['2017/02/10', '2018/02/07', '2019/02/01'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 100, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NOKOMIS BEACH COFFEE',
#   'address': '4956 28TH AVE S',
#   'zipcode': '55417',
#   'neighborhood': 'Keewaydin',
#   'latitude': 44.9128,
#   'longitude': -93.23262,
#   'inspectionidnumber': [180887, 180886, 237061, 286938],
#   'dateofinspection': ['2017/02/06', '2018/01/03', '2019/01/08', '2020/01/08'],
#   'inspectiontype': ['Follow-Up', 'Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 94, 98, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NOKOMIS SQUARE COOPERATIVE',
#   'address': '5015 35TH AVE S',
#   'zipcode': '55417',
#   'neighborhood': 'Minnehaha',
#   'latitude': 44.91168,
#   'longitude': -93.22093,
#   'inspectionidnumber': [41401, 203337, 203336, 255514],
#   'dateofinspection': ['2017/07/05', '2017/09/05', '2018/07/19', '2019/06/24'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine', 'Routine'],
#   'inspectionscore': [90, 100, 96, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "NOLO'S KITCHEN & BAR / THE BASEMENT BAR",
#   'address': '511 WASHINGTON AVE N',
#   'zipcode': '55401',
#   'neighborhood': 'North Loop',
#   'latitude': 44.98618,
#   'longitude': -93.27554,
#   'inspectionidnumber': [231474, 236995, 285912, 285911, 339096],
#   'dateofinspection': ['2017/12/21',
#    '2018/12/18',
#    '2019/01/09',
#    '2019/12/17',
#    '2020/01/14'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [96, 82, 94, 84, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NOMAD WORLD PUB',
#   'address': '501 CEDAR AVE S',
#   'zipcode': '55454',
#   'neighborhood': 'Cedar Riverside',
#   'latitude': 44.96875,
#   'longitude': -93.24692,
#   'inspectionidnumber': [251080, 198108, 251710],
#   'dateofinspection': ['2018/05/30', '2018/10/26', '2019/11/26'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [98, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NOODLES & COMPANY',
#   'address': '300 HENNEPIN AVE E',
#   'zipcode': '55414',
#   'neighborhood': 'Nicollet Island - East Bank',
#   'latitude': 44.98797,
#   'longitude': -93.25563,
#   'inspectionidnumber': [48765, 191941, 251516, 251515, 311577],
#   'dateofinspection': ['2017/03/06',
#    '2018/05/24',
#    '2018/07/10',
#    '2019/05/23',
#    '2019/06/26'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [94, 94, 96, 90, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NOODLES & COMPANY',
#   'address': '3040 EXCELSIOR BLVD',
#   'zipcode': '55416',
#   'neighborhood': 'West Calhoun',
#   'latitude': 44.94759,
#   'longitude': -93.32256,
#   'inspectionidnumber': [48751, 196506, 196505, 248239],
#   'dateofinspection': ['2017/04/20', '2017/06/13', '2018/04/19', '2019/05/03'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine', 'Routine'],
#   'inspectionscore': [90, 98, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORMANDY KITCHEN',
#   'address': '405 8TH ST S',
#   'zipcode': '55404',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97315,
#   'longitude': -93.26743,
#   'inspectionidnumber': [30146, 190596, 189765, 242963, 298684, 298683],
#   'dateofinspection': ['2017/02/01',
#    '2017/03/27',
#    '2018/02/07',
#    '2019/02/13',
#    '2019/03/26',
#    '2020/02/13'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [77, 91, 94, 88, 96, 88],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTH CENTRAL UNIVERSITY',
#   'address': '910 ELLIOT AVE',
#   'zipcode': '55404',
#   'neighborhood': 'Elliot Park',
#   'latitude': 44.96935,
#   'longitude': -93.26149,
#   'inspectionidnumber': [48841, 191092, 245924],
#   'dateofinspection': ['2017/02/22', '2018/02/28', '2019/03/05'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [92, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTH EAST SOCIAL CLUB',
#   'address': '359 13TH AVE NE',
#   'zipcode': '55413',
#   'neighborhood': 'Sheridan',
#   'latitude': 45.00122,
#   'longitude': -93.26181,
#   'inspectionidnumber': [48872, 200117, 200116, 251750, 251749],
#   'dateofinspection': ['2017/05/18',
#    '2017/06/16',
#    '2018/05/18',
#    '2018/07/03',
#    '2019/05/17'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [94, 100, 78, 94, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTH LOOP GALLEY',
#   'address': '729 WASHINGTON AVE N',
#   'zipcode': '55401',
#   'neighborhood': 'North Loop',
#   'latitude': 44.98794,
#   'longitude': -93.27803,
#   'inspectionidnumber': [338343, 349502, 349731, 353780],
#   'dateofinspection': ['2020/01/24', '2020/01/27', '2020/02/06', '2020/02/20'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Follow-Up', 'Follow-Up'],
#   'inspectionscore': [46, 88, 76, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTH MARKET',
#   'address': '4414 HUMBOLDT AVE N',
#   'zipcode': '55412',
#   'neighborhood': 'Webber - Camden',
#   'latitude': 45.03577,
#   'longitude': -93.29833,
#   'inspectionidnumber': [234875, 243063, 298353, 298352, 341551],
#   'dateofinspection': ['2018/02/15',
#    '2019/02/14',
#    '2019/03/27',
#    '2020/01/08',
#    '2020/01/22'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [100, 92, 100, 70, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTH SIDE GRILL AND BBQ',
#   'address': '2118 WEST BROADWAY',
#   'zipcode': '55411',
#   'neighborhood': 'Jordan',
#   'latitude': 45.0038,
#   'longitude': -93.30754,
#   'inspectionidnumber': [266416, 277250, 277249, 335155, 338384],
#   'dateofinspection': ['2018/10/25',
#    '2018/11/27',
#    '2019/10/23',
#    '2019/12/05',
#    '2020/01/16'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up'],
#   'inspectionscore': [96, 100, 84, 86, 86],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTHBOUND SMOKEHOUSE BREWPUB',
#   'address': '2716 38TH ST E',
#   'zipcode': '55406',
#   'neighborhood': 'Standish',
#   'latitude': 44.93431,
#   'longitude': -93.23249,
#   'inspectionidnumber': [191068,
#    196816,
#    203558,
#    196815,
#    247922,
#    247921,
#    307291],
#   'dateofinspection': ['2017/04/24',
#    '2017/07/06',
#    '2017/08/23',
#    '2018/04/11',
#    '2018/06/11',
#    '2019/03/26',
#    '2019/05/21'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [80, 92, 96, 59, 92, 96, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTHEAST BP',
#   'address': '2636 UNIVERSITY AVE NE',
#   'zipcode': '55418',
#   'neighborhood': 'Marshall Terrace',
#   'latitude': 45.01644,
#   'longitude': -93.26359,
#   'inspectionidnumber': [43766, 242976, 242975],
#   'dateofinspection': ['2018/02/09', '2018/03/09', '2020/02/14'],
#   'inspectiontype': ['Routine', 'Follow-Up', 'Routine'],
#   'inspectionscore': [86, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTHEAST YACHT CLUB',
#   'address': '801 MARSHALL ST NE',
#   'zipcode': '55413',
#   'neighborhood': 'St. Anthony West',
#   'latitude': 44.99548,
#   'longitude': -93.26633,
#   'inspectionidnumber': [55739, 196433, 196432, 249329, 252897, 249328],
#   'dateofinspection': ['2017/04/18',
#    '2017/05/18',
#    '2018/04/27',
#    '2018/06/18',
#    '2018/08/08',
#    '2019/04/30'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [90, 96, 88, 88, 94, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTHERN COFFEEWORKS',
#   'address': '1027 WASHINGTON AVE S',
#   'zipcode': '55415',
#   'neighborhood': 'Downtown East',
#   'latitude': 44.97519,
#   'longitude': -93.25366,
#   'inspectionidnumber': [205634, 227827, 228733, 277223],
#   'dateofinspection': ['2017/09/25', '2017/09/27', '2018/10/12', '2019/10/09'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine', 'Routine'],
#   'inspectionscore': [98, 98, 100, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTHERN LIGHTS TEA COMPANY',
#   'address': '811 LASALLE AVE',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97592,
#   'longitude': -93.27444,
#   'inspectionidnumber': [55762, 234911],
#   'dateofinspection': ['2017/12/04', '2019/11/05'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [94, 94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORTHSIDE STEAK HOUSE',
#   'address': '4330 LYNDALE AVE N',
#   'zipcode': '55412',
#   'neighborhood': 'Camden Industrial',
#   'latitude': 45.03448,
#   'longitude': -93.2876,
#   'inspectionidnumber': [223151, 233144, 233143, 279379, 279378, 337170],
#   'dateofinspection': ['2017/11/16',
#    '2017/12/18',
#    '2018/11/14',
#    '2018/12/14',
#    '2019/11/14',
#    '2019/12/30'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [94, 100, 90, 92, 86, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NORWAY HOUSE',
#   'address': '913 FRANKLIN AVE E',
#   'zipcode': '55404',
#   'neighborhood': 'Ventura Village',
#   'latitude': 44.96243,
#   'longitude': -93.26026,
#   'inspectionidnumber': [276703, 285136],
#   'dateofinspection': ['2018/12/18', '2019/12/18'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NUMBER FRY N GRILL',
#   'address': '1922 CLINTON AVE',
#   'zipcode': '55404',
#   'neighborhood': "Steven's Square - Loring Heights",
#   'latitude': 44.96298,
#   'longitude': -93.27185,
#   'inspectionidnumber': [191935, 197677, 197676, 249057, 249056],
#   'dateofinspection': ['2017/05/02',
#    '2017/06/29',
#    '2018/05/02',
#    '2018/07/10',
#    '2019/07/03'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [74, 96, 92, 100, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NUTTY SNACKS',
#   'address': '2608 BLAISDELL AVE',
#   'zipcode': '55408',
#   'neighborhood': 'Whittier',
#   'latitude': 44.95522,
#   'longitude': -93.28013,
#   'inspectionidnumber': [247947, 253059],
#   'dateofinspection': ['2018/06/19', '2020/01/15'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [96, 92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'NYES BAR',
#   'address': '112 HENNEPIN AVE E',
#   'zipcode': '55414',
#   'neighborhood': 'Nicollet Island - East Bank',
#   'latitude': 44.98711,
#   'longitude': -93.25803,
#   'inspectionidnumber': [237238, 246041],
#   'dateofinspection': ['2018/03/14', '2019/04/18'],
#   'inspectiontype': ['Routine', 'Routine'],
#   'inspectionscore': [98, 98],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': "O'DONOVANS IRISH PUB",
#   'address': '700 1ST AVE N',
#   'zipcode': '55403',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97862,
#   'longitude': -93.2766,
#   'inspectionidnumber': [124442,
#    124441,
#    232386,
#    242654,
#    248216,
#    251964,
#    232385,
#    279990,
#    279989,
#    337149],
#   'dateofinspection': ['2017/01/10',
#    '2017/11/02',
#    '2018/02/09',
#    '2018/04/18',
#    '2018/06/04',
#    '2018/07/12',
#    '2018/11/15',
#    '2018/12/18',
#    '2019/11/14',
#    '2020/01/28'],
#   'inspectiontype': ['Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [100, 94, 98, 98, 98, 98, 74, 66, 68, 82],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'OAK GROVE CARE CENTER',
#   'address': '1822 PARK AVE',
#   'zipcode': '55404',
#   'neighborhood': 'Ventura Village',
#   'latitude': 44.96429,
#   'longitude': -93.26559,
#   'inspectionidnumber': [56505, 196709, 247856],
#   'dateofinspection': ['2017/04/18', '2018/04/11', '2019/04/08'],
#   'inspectiontype': ['Routine', 'Routine', 'Routine'],
#   'inspectionscore': [100, 98, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'OCEANAIRE SEAFOOD ROOM',
#   'address': '50 6TH ST S',
#   'zipcode': '55402',
#   'neighborhood': 'Downtown West',
#   'latitude': 44.97841,
#   'longitude': -93.27178,
#   'inspectionidnumber': [62880,
#    230548,
#    233272,
#    230547,
#    277636,
#    277635,
#    334503],
#   'dateofinspection': ['2017/10/18',
#    '2017/11/16',
#    '2018/01/12',
#    '2018/10/25',
#    '2018/11/26',
#    '2019/10/22',
#    '2019/11/21'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [72, 86, 94, 92, 96, 72, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'OLIVE & LAMB EATERY',
#   'address': '2424 UNIVERSITY AVE NE',
#   'zipcode': '55418',
#   'neighborhood': 'Prospect Park - East River Road',
#   'latitude': 44.97322,
#   'longitude': -93.22188,
#   'inspectionidnumber': [313600],
#   'dateofinspection': ['2019/08/12'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [94],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'OLYMPIC CAFE',
#   'address': '923 WEST BROADWAY',
#   'zipcode': '55411',
#   'neighborhood': 'Near - North',
#   'latitude': 44.99889,
#   'longitude': -93.29216,
#   'inspectionidnumber': [63076,
#    196523,
#    196522,
#    248273,
#    251555,
#    252060,
#    248272],
#   'dateofinspection': ['2017/04/19',
#    '2017/06/05',
#    '2018/04/18',
#    '2018/05/29',
#    '2018/06/01',
#    '2018/10/02',
#    '2019/04/24'],
#   'inspectiontype': ['Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up',
#    'Follow-Up',
#    'Follow-Up',
#    'Routine'],
#   'inspectionscore': [88, 98, 90, 94, 94, 100, 100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'OLYMPIC CAFE 2',
#   'address': '2117 WEST BROADWAY',
#   'zipcode': '55411',
#   'neighborhood': 'Willard - Hay',
#   'latitude': 45.00324,
#   'longitude': -93.30786,
#   'inspectionidnumber': [124857, 233510, 280577, 280576, 337632],
#   'dateofinspection': ['2017/11/20',
#    '2018/11/20',
#    '2018/12/31',
#    '2019/11/19',
#    '2020/01/02'],
#   'inspectiontype': ['Routine',
#    'Routine',
#    'Follow-Up',
#    'Routine',
#    'Follow-Up'],
#   'inspectionscore': [100, 90, 92, 86, 96],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ONE MINNEAPOLIS BREWING',
#   'address': '618 5TH ST N',
#   'zipcode': '55401',
#   'neighborhood': 'North Loop',
#   'latitude': 44.98547,
#   'longitude': -93.28014,
#   'inspectionidnumber': [337061],
#   'dateofinspection': ['2020/01/09'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [92],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  {'inspect_name': 'ONE STOP',
#   'address': '1604 WEST BROADWAY',
#   'zipcode': '55411',
#   'neighborhood': 'Jordan',
#   'latitude': 44.9997,
#   'longitude': -93.3017,
#   'inspectionidnumber': [303153],
#   'dateofinspection': ['2019/04/24'],
#   'inspectiontype': ['Routine'],
#   'inspectionscore': [100],
#   'updated': 'Sun, Mar 15, 2020 at 04:27 PM'},
#  ...]

# %% [markdown]
# # Yelp Data

# %%
Bad_Categories = [
 'Adult Entertainment','Airport Shuttles','Apartments','Appliances & Repair','Arcades','Art Galleries','Art Museums','Art Schools',
 'Arts & Crafts','Assisted Living Facilities','Auto Detailing','Auto Insurance','Auto Repair','Axe Throwing','Bakeries','Banks & Credit Unions','Barbers',
 'Beverage Store','Bike Repair/Maintenance','Bikes','Blood & Plasma Donation Centers','Body Shops','Bookstores','Bowling','Building Supplies','Cabinetry',
 'Candy Stores','Car Wash','Caterers','Cardiologists','Chiropractors','Chocolatiers & Shops','Churches','Colleges & Universities','Comedy Clubs',
 'Community Centers','Community Service/Non-Profit','Convenience Stores','Cooking Classes','Cooking Schools','Cosmetic Dentists',
 'Cosmetics & Beauty Supply','CSA','Cultural Center','Dance Clubs','Department Stores','Discount Store','Drugstores','Electronics',
 'Employment Agencies','Endodontists','Farmers Market','Financial Advising','Florists','Furniture Stores','Gas Stations','General Dentistry',
 'Gift Shops','Golf','Grocery','Guest Houses','Gyms','Hair Extensions','Hair Salons','Hardware Stores','Health Markets','Historical Tours',
 'Home & Rental Insurance','Hospitals','Hotels','Imported Food','International Grocery','Interior Design','Investing','IT Services & Computer Repair',
 'Jazz & Blues','Jewelry','Karaoke','Kitchen Supplies','Knife Sharpening','Kombucha','Landmarks & Historical Buildings','Landscaping','Laser Eye Surgery/Lasik',
 'Life Insurance','Limos','Macarons','Massage Therapy','Meat Shops','Medical Centers','Medical Spas','Men\'s Clothing','Mobile Phone Accessories',
 'Mobile Phone Repair','Mobile Phones','Mortgage Brokers','Museums','Music & DVDs','Music Venues','Nail Salons','Nurseries & Gardening',
 'Ophthalmologists','Organic Stores','Orthopedists','Outlet Stores','Parking','Parks','Party & Event Planning','Party Bus Rentals',
 'Performing Arts','Personal Care Services','Pharmacy','Popcorn Shops','Print Media','Professional Sports Teams','Psychiatrists','Public Transportation',
 'Radio Stations','Religious Organizations','Retirement Homes','Seafood Markets','Shopping Centers','Skilled Nursing','SkinCare','Social Clubs','Spray Tanning','Strip Clubs',
 'Tattoo','Taxis','Tires','Trainers','Venues & Event Spaces','Videos & Video Game Rental','Vinyl Records','Vitamins & Supplements','Waxing',
 'Wedding Planning','Wheel & Rim Repair','Wholesale Stores','Wigs','Wine Tours','Women\'s Clothing','Yoga'
]

# %%
# Download restaurants as the search parameter.

i=0

headers = {'Authorization': 'Bearer %s' % yelp_key}

url='https://api.yelp.com/v3/businesses/search'

print('Downloading Yelp Data for each restaurant...',flush=True)

no_yelp=[]

for item in grand_master_list:
    
    if item['inspect_name'].split()[0] != "THE":
        params = {
            'term':item['inspect_name'].split()[0],
    #         'term':item['inspect_name'],
            'latitude':item['latitude'],
            'longitude':item['longitude'],
            'radius':200,
            "sort_by":"distance"
            }
    else:
    
        params = {
            'term':item['inspect_name'].split()[1],
    #         'term':item['inspect_name'],
            'latitude':item['latitude'],
            'longitude':item['longitude'],
            'radius':200,
            "sort_by":"distance"
            }
        
    response=requests.get(url, params=params, headers=headers)
    if response.status_code == 200:
        yelp= response.json()['businesses']
        if len(yelp)>0:
            if 'categories' in yelp[0]:
                categories=[]
                for cat in yelp[0]['categories']:
                    category = cat['title']
                    if category not in Bad_Categories:
                        categories.append(category)
                    if len(categories) != 0:
                        item.update(yelp_categories=categories)
                        if 'name' in yelp[0]: 
                            item.update(yelp_name = yelp[0]['name'])
                        if 'id' in yelp[0]:
                            item.update(yelp_id= yelp[0]['id'])
                        if 'price' in yelp[0]:
                            item.update(yelp_price=yelp[0]['price'])
                        if 'url'in yelp[0]:
                            item.update(yelp_url=yelp[0]['url'])
                        if 'transactions' in yelp[0]:
                            item.update(yelp_transactions=yelp[0]['transactions'])
                        if 'display_phone' in yelp[0]:
                            item.update(yelp_phone=yelp[0]['display_phone'])
                        if len('display_address') in yelp[0]['location'] > 1:
                            item.update(address=yelp[0]['location']['display_address'][0]+", "+yelp[0]['location']['display_address'][1])
                        if 'rating' in yelp[0]:
                            item.update(yelp_rating=yelp[0]['rating'])
                        if 'review_count' in yelp[0]:
                            item.update(yelp_reviews=yelp[0]['review_count'])
                        if 'latitude' in yelp[0]:
                            item.update(latitude=yelp[0]['latitude'])
                        if 'longitude' in yelp[0]:
                            item.update(longitude=yelp[0]['longitude'])
                        currentDT=datetime.datetime.now()
                        item.update(updated = currentDT.strftime("%a, %b %d, %Y at %I:%M %p"))
          
    elif response.status_code == 400:
        print('400 Bad Request')
        break
        
    print("Restaurants Remaining: {:4}".format(len(grand_master_list)-i), end="\r",flush=True)
    
    i+=1
    
for item in grand_master_list:
    if 'yelp_rating' not in item:
        no_yelp.append(item)
        grand_master_list.remove(item)

for item in grand_master_list:
    if 'yelp_reviews' not in item:
        no_yelp.append(item)
        grand_master_list.remove(item)
        
for item in grand_master_list:
    if 'yelp_categories' not in item:
        no_yelp.append(item)
        grand_master_list.remove(item)
        
for item in grand_master_list:
    if 'yelp_name' not in item:
        no_yelp.append(item)
        grand_master_list.remove(item)

no_yelp_df=pd.DataFrame(no_yelp)
no_yelp_df.to_csv('DataFiles/NoYelp.csv')

print('---------------',flush=True)
print(f'Yelp data downloaded and added to grand_master_list...',flush=True)
print(f'{len(no_yelp)} records from the inspections list were not found in Yelp search (name, categories, rating, and reviews).',flush=True)  
print('Those records have been removed from grand_master_list and saved to a csv called "NoYelp.csv".',flush=True)
print(f'There are now {len(grand_master_list)} restaurants remaining in grand_master_list.', flush=True)
print('---------------',flush=True)
# Out:
# Downloading Yelp Data for each restaurant...
# ---------------aining:    1
# Yelp data downloaded and added to grand_master_list...
# 458 records from the inspections list were not found in Yelp search (name, categories, rating, and reviews).
# Those records have been removed from grand_master_list and saved to a csv called "NoYelp.csv".
# There are now 1078 restaurants remaining in grand_master_list.
# ---------------

# %%
#This code snippet iterates through the categories in each record and creates a list of unique category names.

category_dict={}
for items in grand_master_list:
    if 'yelp_categories' in items:
        for category in items['yelp_categories']:
        
            if category not in category_dict.keys():
                category_dict.update({category:1})
            else:
                category_dict[category]+=1

sorted_categories=sorted(category_dict.keys(), key=lambda x:x.lower())

sorted_cat_dict= {}
for key in sorted_categories:
    sorted_cat_dict.update({key: category_dict[key]})

# %%
lack_similarity = []

for items in grand_master_list:
    if 'yelp_name' in items:
        s = SequenceMatcher(None, items['inspect_name'], items['yelp_name'].upper())
        s_ratio = s.ratio()
        if s_ratio <.25:
            dict={}
            dict["INSPECTION"] = items['inspect_name'].lower()
            dict["YELP"] = items['yelp_name'].lower()
            dict["RATIO"] = str(s.ratio())
            lack_similarity.append(dict)
            grand_master_list.remove(items)
            
yelp_lack_similarity_df=pd.DataFrame(lack_similarity)
yelp_lack_similarity_df.to_csv('DataFiles/YelpLackSimilarity.csv')

print(f'{len(lack_similarity)} restaurants downloaded from Yelp had less than 25% similarity in name when compared to the name in the inspections DB.', flush=True)
print('Assuming these are different establishments, they have been removed from grand_master_list.', flush=True)
print('They have been saved to a csv called "YelpLackSimilarity.csv".', flush=True)
print(f'There are now {len(grand_master_list)} restaurants left in grand_master_list.', flush=True)
print('---------------',flush=True)
# Out:
# 52 restaurants downloaded from Yelp had less than 25% similarity in name when compared to the name in the inspections DB.
# Assuming these are different establishments, they have been removed from grand_master_list.
# They have been saved to a csv called "YelpLackSimilarity.csv".
# There are now 1026 restaurants left in grand_master_list.
# ---------------

# %% [markdown]
# #Google Data

# %%
print('Appending Google Data to grand_master_list...   This will take some time, as we match each record...',flush=True)

url = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json?'

i=0

no_google=[]

for item in grand_master_list:
    
    params = {
        'key':google_key,
        'input':item['inspect_name'],
        'inputtype':'textquery',
        'locationbias': 'point:' + str(item['latitude']) + ", " + str(item['longitude']),
        'radius': 100,
        'fields':'place_id,formatted_address,name,rating,user_ratings_total,price_level'
        }
    
    response = requests.get(url, params=params)
    json=response.json()
    
    if len(response.json()['candidates'])>0:
        if 'name' in json['candidates'][0]: 
            item.update(google_name =json['candidates'][0]['name'])
        if 'formatted_address' in json['candidates'][0]: 
            item.update(address =json['candidates'][0]['formatted_address'])
        if 'place_id' in json['candidates'][0]:
            item.update(google_id=json['candidates'][0]['place_id'])
        if 'rating' in json['candidates'][0]:
            item.update(google_rating=json['candidates'][0]['rating'])
        if 'user_ratings_total' in json['candidates'][0]:
            item.update(google_reviews = json['candidates'][0]['user_ratings_total'])
        if 'price_level' in json['candidates'][0]:
            item.update(google_price =json['candidates'][0]['price_level'])
        currentDT=datetime.datetime.now()
        item.update(updated = currentDT.strftime("%a, %b %d, %Y at %I:%M %p"))
    
    print("Restaurants Remaining: {:4}".format(len(grand_master_list)-i), end="\r",flush=True)
    
    i+=1

print('---------------',flush=True)
print(f'Google data downloaded and added to grand_master_list...',flush=True)

print(f'There are now {len(grand_master_list)} restaurants remaining in grand_master_list.', flush=True)
print('---------------',flush=True)
# Out:
# Appending Google Data to grand_master_list...   This will take some time, as we match each record...
# ---------------aining:    1
# Google data downloaded and added to grand_master_list...
# There are now 1026 restaurants remaining in grand_master_list.
# ---------------

# %%
for item in grand_master_list:
    if 'google_rating' not in item:
        no_google.append(item)
        grand_master_list.remove(item)
    
for item in grand_master_list:
    if 'google_reviews' not in item:
        no_google.append(item)
        grand_master_list.remove(item)
        
for item in grand_master_list:
    if 'google_name' not in item:
        no_google.append(item)
        grand_master_list.remove(item)
        
no_google_df =  pd.DataFrame(no_google)
no_google_df.to_csv('DataFiles/NoGoogle.csv')

print(f'{len(no_google)} records from the inspections list were not found in Google search (rating and reviews).',flush=True)  
print('Those records have been removed from grand_master_list and saved to a csv called "NoGoogle.csv".',flush=True)

print(f'There are now {len(grand_master_list)} restaurants remaining in grand_master_list.', flush=True)
print('---------------',flush=True)
# Out:
# 7 records from the inspections list were not found in Google search (rating and reviews).
# Those records have been removed from grand_master_list and saved to a csv called "NoGoogle.csv".
# There are now 1019 restaurants remaining in grand_master_list.
# ---------------

# %%
google_lack_similarity = []

for items in grand_master_list:
    if 'google_name' in items:
        s = SequenceMatcher(None, items['inspect_name'], items['google_name'].upper())
        s_ratio = s.ratio()
        if s_ratio <.25:
            dict={}
            dict["INSPECTION"] = items['inspect_name'].lower()
            dict["GOOGLE"] = items['google_name'].lower()
            dict["RATIO"] = str(s.ratio())
            lack_similarity.append(dict)
            grand_master_list.remove(items)
            
google_lack_similarity_df=pd.DataFrame(lack_similarity)
google_lack_similarity_df.to_csv('DataFiles/GoogleLackSimilarity.csv')

print(f'{len(google_lack_similarity)} restaurants downloaded from Google had less than 25% similarity in name when compared to the name in the inspections DB.', flush=True)
print('Assuming these are different establishments, they have been removed from grand_master_list.', flush=True)
print('They have been saved to a csv called "GoogleLackSimilarity.csv".', flush=True)
print(f'There are now {len(grand_master_list)} restaurants left in grand_master_list.', flush=True)
print('---------------',flush=True)
# Out:
# 0 restaurants downloaded from Google had less than 25% similarity in name when compared to the name in the inspections DB.
# Assuming these are different establishments, they have been removed from grand_master_list.
# They have been saved to a csv called "GoogleLackSimilarity.csv".
# There are now 1015 restaurants left in grand_master_list.
# ---------------

# %%
# Create a new Aggregate Score and Review Count  based on Yelp Rating and Google Rating and add Column to the DataFrame


# Function that computes the weighted rating of each restaurant
def aggregate_rating (x):
    yelp_reviews = x['yelp_reviews']
    yelp_rating = x['yelp_rating']
    google_reviews = x['google_reviews']
    google_rating = x['google_rating']
    # Calculation
    return ((yelp_rating*yelp_reviews)+(google_rating*google_reviews))/(yelp_reviews+google_reviews)

def total_reviews (x):
    yelp_reviews = x['yelp_reviews']
    google_reviews = x['google_reviews']
    return yelp_reviews+google_reviews

master_df=pd.DataFrame(grand_master_list)
master_df['agg_rating'] = master_df.apply(aggregate_rating, axis=1)
master_df['total_reviews'] = master_df.apply(total_reviews, axis=1)
master_df.agg_rating =master_df.agg_rating.round(2)

master_df.to_csv('DataFiles/MasterList.csv')

print('agg_rating and total_reviews fields created by combining Yelp and Google Ratings and Reviews.', flush=True)
print('grand_master_list is now complete, has been saved as csv named "MasterList.csv".', flush=True)
print('---------------',flush=True)
# Out:
# agg_rating and total_reviews fields created by combining Yelp and Google Ratings and Reviews.
# grand_master_list is now complete, has been saved as csv named "MasterList.csv".
# ---------------

# %%
#Postgres username, password, and database name
ipaddress = 'localhost'
port = '5432'
username = username
password = password 
dbname = 'Minneapolis_Restaurants'
# A long string that contains the necessary Postgres login information
postgres_str = f'postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'

# %%
# Creates Classes which will serve as the anchor points for our Table, loads table to Postgres and uplads the data

Base = declarative_base()
engine = create_engine(postgres_str)

class GrandMasterData(Base):
    __tablename__ = 'grandmasterdata'
    index=Column(Integer,primary_key=True,autoincrement=True)
    inspect_name=Column(String,nullable=False)
    address=Column(String)
    zipcode=Column(String)
    neighborhood=Column(String)
    inspectionidnumber=Column(String)
    dateofinspection=Column(String)
    inspectionscore=Column(String)
    inspectiontype=Column(String)
    updated=Column(String)
    yelp_id=Column(String,nullable=False)
    yelp_name=Column(String)
    yelp_url=Column(String)
    yelp_price=Column(Integer)
    latitude=Column(Float(20))
    longitude=Column(Float(20))
    yelp_phone=Column(String)
    yelp_categories=Column(String)
    yelp_transactions=Column(String)
    yelp_rating=Column(Float(10))
    yelp_reviews=Column(Integer)
    google_name=Column(String)
    google_id=Column(String)
    google_rating=Column(Float(10))
    google_reviews=Column(Integer)
    google_price=Column(Integer)
    agg_rating=Column(Float)
    total_reviews=Column(Float)
                   
Base.metadata.create_all(engine)

master_df.to_sql('grandmasterdata', engine, if_exists='replace', index=True)

print(f'Table "grandmasterdata" uploaded to postgreSQL database "Minneapolis_Restaurants".',flush=True)
print('---------------')
# Out:
# Table "grandmasterdata" uploaded to postgreSQL database "Minneapolis_Restaurants".
# ---------------

# %%
# Creates Classes which will serve as the anchor points for our Table, loads table to Postgres and uplads the data

Base = declarative_base()
engine = create_engine(postgres_str)

class InspectionsDetail(Base):
    __tablename__ = 'inspectionsdetail'
    inspectionidnumber=Column(String,primary_key=True)
    dateofinspection=Column(String)
    businessname=Column(String)
    fulladdress=Column(String)
    inspectiontype=Column(String)
    inspectionscore=Column(String)
    inspectionresult=Column(String)
    foodcodeitem=Column(String)
    foodcodetext=Column(String)
    inspectorcomments=Column(String)
    violationpriority=Column(String)
    violationstatus=Column(String)
    violationpoints=Column(String)
                   
Base.metadata.create_all(engine)

inspections_detail.to_sql('inspectionsdetail', engine, if_exists='replace', index=True)

print(f'Table "inspectionsdetail" uploaded to postgreSQL database "Minneapolis_Restaurants".',flush=True)
print('---------------',flush=True)
print("DONE.  Don't forget to fix the SQL data types! Use the DataTypeChange script to fix your Minneapolis_Restaurants DB",flush=True)
# Out:
# Table "inspectionsdetail" uploaded to postgreSQL database "Minneapolis_Restaurants".
# ---------------
# DONE.  Don't forget to fix the SQL data types! Use the DataTypeChange script to fix your Minneapolis_Restaurants DB
